# %%
def simple_interest(principal, rate, time):
    A=principal*(1+(rate/100)*time)
    return A

principal=int(input("enter principal"))  
rate=int(input("enter rate")) 
time=int(input("enter time")) 

    
simple_interest_answer=simple_interest(principal,rate,time) 
print(simple_interest_answer)
# Out:
# enter principal 4
# enter rate 4
# enter time 4
# 4.64

# %% [markdown]
# ![simpleinterest.jpeg](attachment:simpleinterest.jpeg)

# %%
def compound_interest(principal, rate, time,compound_per_year):
    A=principal*(1+(rate/compound_per_year))**(compound_per_year*time)
    return A
principal=int(input("enter principal"))  
rate=int(input("enter rate")) 
time=int(input("enter time")) 
compound_per_year=int(input("enter compound per year")) 

    
compound_interest_answer=compound_interest(principal,rate,time,compound_per_year) 
print(compound_interest_answer)
# Out:
# enter principal 4
# enter rate 4
# enter time 4
# enter compound per year 4
# 262144.0

# %% [markdown]
# ![compound_interest.jpeg](attachment:compound_interest.jpeg)

# %%
def Annuity_plan(PMT,R,N,t):
    A=(PMT)*((((1+(R/N))**(N*t))-1)/(R/N))
    print(A)
principal=int(input("enter principal"))  
rate=int(input("enter rate")) 
time=int(input("enter time")) 
compound_per_year=int(input("enter compound per year")) 

    
Annunity_plan_answer=Annuity_plan(principal,rate,compound_per_year,time) 
print(Annunity_plan_answer)
# Out:
# enter principal 4
# enter rate 4
# enter time 4
# enter compound per year 4
# 262140.0
# None

# %% [markdown]
# ![annunuity plan.jpeg](<attachment:annunuity plan.jpeg>)
