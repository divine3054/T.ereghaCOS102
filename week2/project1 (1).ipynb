# %%
LET SUM=0
INPUT itemname
INPUT itemprice
LET SUM =SUM+itemprice
WHILE more_items
   INPUT itemname
   INPUT itemprice
   LET SUM =SUM+itemprice
LET receipt_price = sum

# %% [markdown]
# ![project1a.drawio (1).png](attachment:e6c15275-1f1e-47d1-a427-121054377241.png)

# %% [markdown]
# ![morning_routine.drawio (1).png](attachment:a162fa23-e7bc-40f1-a40c-7f7b4918a69d.png)

# %% [markdown]
# ![algorithm.drawio.png](attachment:ca56a14c-ba7b-465f-9ab7-65c7df3269df.png)
